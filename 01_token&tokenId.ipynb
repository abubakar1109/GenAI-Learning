# %% [markdown]
# <a href="https://colab.research.google.com/github/abubakar1109/GenAI-Learning/blob/main/01_token%26tokenId.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text="what is capital of pakistan?"

# %%
import tiktoken

# %%
tokenizer =tiktoken.encoding_for_model(model_name="gpt-5")

# %%
tokenID=tokenizer.encode(text)

# %%
tokenID
# Out:
# [13347, 382, 9029, 328, 155730, 30]

# %%
resultID= [77382, 328, 155730, 382, 52980, 25792, 13]

# %%
tokenizer.decode(resultID)
# Out:
# 'Capital of pakistan is islamabad.'
